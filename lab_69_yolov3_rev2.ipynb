# %% [markdown]
# <a href="https://colab.research.google.com/github/rtajeong/M4_2026/blob/main/lab_69_yolov3_rev2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Yolov3 연습
# - different platform
# - Pytorch with CUDA

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# !git clone https://github.com/ultralytics/yolov3.git
# %cd yolov3
# Out:
# fatal: destination path 'yolov3' already exists and is not an empty directory.
# /content/yolov3/yolov3

# %%
# !pwd
# Out:
# /content/yolov3

# %%
# !pwd
# Out:
# /content/yolov3/yolov3

# %% [markdown]
# - detect.py runs YOLOv3 inference on a variety of sources, downloading models automatically from the YOLOv3 release, and saving results to runs/detect.

# %%
# !python3 detect.py --weights yolov3-spp.pt
# Out:
# detect: weights=['yolov3-spp.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv3 🚀 v9.6.0-337-g8894ca1 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# YOLOv3-spp summary: 269 layers, 62971933 parameters, 0 gradients, 156.7 GFLOPs
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1 tie, 42.8ms
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 3 ties, 1 tennis racket, 59.3ms
# Speed: 0.5ms pre-process, 51.1ms inference, 42.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !python3 detect.py --help

# %%
# !pwd
# Out:
# /content/yolov3

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)

# %%
img = mpimg.imread('./runs/detect/exp/zidane.jpg')
plt.imshow(img)

# %% [markdown]
# ### Using Yolov3-tiny

# %%
# !python3 detect.py --weights yolov3-tiny.pt
img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)
# Out:
# detect: weights=['yolov3-tiny.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv3 🚀 v9.6.0-337-g8894ca1 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# YOLOv3-tiny summary: 48 layers, 8849182 parameters, 0 gradients, 13.2 GFLOPs
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 1 surfboard, 14.8ms
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 3 persons, 1 tie, 18.1ms
# Speed: 0.7ms pre-process, 16.4ms inference, 29.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
img = mpimg.imread('./runs/detect/exp/zidane.jpg')
plt.imshow(img)

# %%
# !python3 detect.py --weights yolov3.pt
img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)
# Out:
# detect: weights=['yolov3.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv3 🚀 v9.6.0-337-g8894ca1 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# ...
# 100% 119M/119M [00:02<00:00, 45.2MB/s]
#
# Fusing layers...
# YOLOv3 summary: 261 layers, 61922845 parameters, 0 gradients, 155.9 GFLOPs
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bicycle, 1 bus, 43.7ms
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 49.9ms
# Speed: 0.5ms pre-process, 46.8ms inference, 27.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
img = mpimg.imread('./runs/detect/exp/zidane.jpg')
plt.imshow(img)

# %%
# !pwd
# Out:
# /content/yolov3
